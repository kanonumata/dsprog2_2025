# %% [markdown]
# # Python演習課題1

# %% [markdown]
# ## 課題1

# %% [markdown]
# ### 問1
#
# 文字列"datascience"の文字を逆に（末尾から先頭に向かって）並べた文字列を出力してください

# %% [markdown]
# メモ
# スライスを使う
# reversed_string = original_string[::**-1**]

# %%
original_string = "datascience"

reversed_string = original_string[::-1]

print(f"元の文字列: {original_string}")
print(f"反転後の文字列: {reversed_string}")
# Out:
# 元の文字列: datascience
# 反転後の文字列: ecneicsatad

# %% [markdown]
# ### 問2
#
# 「ヘエルスシトンニキア」という文字列の1,3,5,7,9文字目を取り出して連結した文字列を出力してください

# %%
original_string = "ヘエルスシトンニキア"

result_string = original_string[::2]

print(f"元の文字列: {original_string}")
print(f"取り出した文字: {result_string}")
# Out:
# 元の文字列: ヘエルスシトンニキア
# 取り出した文字: ヘルシンキ

# %% [markdown]
# ### 問3
#
# 「ヘルシンキ」＋「エストニア」の文字を先頭から交互に連結して文字列「ヘエルスシトンニキア」を出力してください

# %% [markdown]
# メモ
# zip()関数を使って、それぞれの文字列の文字をペアにする
# リスト内包表記で各ペアの文字を平らに並べ（['ヘ', 'エ', 'ル', 'ス', ...]）、
# ''.join() で一つの文字列に結合する

# %%
string1 = "ヘルシンキ" # 5文字
string2 = "エストニア" # 5文字

combined_string = "".join([c1 + c2 for c1, c2 in zip(string1, string2)])

print(f"文字列 1: {string1}")
print(f"文字列 2: {string2}")
print(f"連結結果: {combined_string}")

# %% [markdown]
# ### 問4
#
# "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan"という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成してください

# %%
sentence = "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan"

words = sentence.split()

word_lengths = [len(word) for word in words]

print(f"元の文章:\n{sentence}")
print(f"単語リスト:\n{words}")
print(f"文字数リスト:\n{word_lengths}")
# Out:
# 元の文章:
# Character education based on the fundamental spirit of Buddhism and the Shiguzeigan
# 単語リスト:
# ['Character', 'education', 'based', 'on', 'the', 'fundamental', 'spirit', 'of', 'Buddhism', 'and', 'the', 'Shiguzeigan']
# 文字数リスト:
# [9, 9, 5, 2, 3, 11, 6, 2, 8, 3, 3, 11]

# %% [markdown]
# ### 問5
#
# "It is not the strongest of the species that survives, nor the most intelligent that survives. It is the one that is most adaptable to change."という文を単語に分解し，1, 2, 5, 6, 8, 9, 16番目の単語の先頭の2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）を格納した辞書を作成してください

# %%
sentence = "It is not the strongest of the species that survives, nor the most intelligent that survives. It is the one that is most adaptable to change."
target_indices = [1, 2, 5, 6, 8, 9, 16] 

cleaned_sentence = sentence.replace(",", "").replace(".", "")
words = cleaned_sentence.split()

result_dict = {}

for index in target_indices:
    
    list_index = index - 1

    word = words[list_index]

    first_two_chars = word[:2]

    result_dict[first_two_chars] = index

print(f"単語リスト:\n{words}")
print(f"指定インデックス: {target_indices}")
print(f"作成された辞書:\n{result_dict}")
# Out:
# 単語リスト:
# ['It', 'is', 'not', 'the', 'strongest', 'of', 'the', 'species', 'that', 'survives', 'nor', 'the', 'most', 'intelligent', 'that', 'survives', 'It', 'is', 'the', 'one', 'that', 'is', 'most', 'adaptable', 'to', 'change']
# 指定インデックス: [1, 2, 5, 6, 8, 9, 16]
# 作成された辞書:
# {'It': 1, 'is': 2, 'st': 5, 'of': 6, 'sp': 8, 'th': 9, 'su': 16}
