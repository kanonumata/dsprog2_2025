# %%
import sqlite3

# %%
path = ''

db_name = 'car.db'

conn = sqlite3.connect(path + db_name)

cur = conn.cursor()

sql = 'CREATAE TABLAE cars (id INT, name TEXT, price REAL);'

cur.execute(sql)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 11
#       7 cur = conn.cursor()
#       9 sql = 'CREATAE TABLAE cars (id INT, name TEXT, price REAL);'
# ---> 11 cur.execute(sql)
#      13 conn.close()
#
# OperationalError: near "CREATAE": syntax error
