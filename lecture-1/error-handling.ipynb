# %%
x = 1
y = 0

# %%
x/y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x/y
#
# ZeroDivisionError: division by zero

# %%
try:
    result = x/y
except ZeroDivisionError as e:
    result = None
    print("エラーが起きました", e)
    print("0で割ることはできません。結果をNoneに設定します。")


print("結果", result)
# Out:
# エラーが起きました division by zero
# 0で割ることはできません。結果をNoneに設定します。
# 結果 None

# %%
try:
    result = x/z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました。",e)
    print("0で割ることはできません。結果をNoneに設定します。")
except NameError as e:
    result=None
    print("エラーが発生しました。",e)
    print("0で割ることはできません。結果をNoneに設定します。")

print("結果",result)
# Out:
# エラーが発生しました。 name 'z' is not defined
# 0で割ることはできません。結果をNoneに設定します。
# 結果 None

# %%
z=3

try:
    result = x/z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました。",e)
    print("0で割ることはできません。結果をNoneに設定します。")
except NameError as e:
    result=None
    print("エラーが発生しました。",e)
    print("0で割ることはできません。結果をNoneに設定します。")
else:
    print("エラーが発生しませんでした。計算結果を表示します。")

print("結果",result)
# Out:
# エラーが発生しませんでした。計算結果を表示します。
# 結果 0.3333333333333333

# %%
z=0

try:
    result = x/z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました。",e)
    print("0で割ることはできません。結果をNoneに設定します。")
except NameError as e:
    result=None
    print("エラーが発生しました。",e)
    print("0で割ることはできません。結果をNoneに設定します。")
else:
    print("エラーが発生しませんでした。計算結果を表示します。")
finally:
    print("計算処理が終了しました。")
print("結果",result)
# Out:
# エラーが発生しました。 division by zero
# 0で割ることはできません。結果をNoneに設定します。
# 計算処理が終了しました。
# 結果 None

# %%
x=1
y=0
z=3

try:
    result=x/y
except Exception as e:
    result=None
    print("エラーが発生しました。",e)
    print("エラーオブジェクト",type(e))
    print("エラーが発生したため、結果をNoneに設定します。")
else:
    print("エラーは発生しませんでした。")
finally:
    print("計算処理が終了しました。")

print("結果",result)
# Out:
# エラーが発生しました。 division by zero
# エラーオブジェクト <class 'ZeroDivisionError'>
# エラーが発生したため、結果をNoneに設定します。
# 計算処理が終了しました。
# 結果 None

# %%
import requests

# %%
url ="https://www.muashino-u.ac.jp"
response = requests.get(url)
print(f"ステータスコード：{response.status_code}")

response.reise_status()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 url ="https://www.muashino-u.ac.jp"
# ----> 2 response = requests.get(url)
#       3 print(f"ステータスコード：{response.status_code}")
#       5 response.reise_status()
#
# NameError: name 'requests' is not defined

# %%
import requests
url ="https://www.muashino-u.ac.jp"

try:
    response = requests.get(url)
    response.raise_for_status()
except requests.exceptions.HTTPError as e:
    print("HTPEエラーが発生しました。")
except requests.exceptions.RequestException as e:
    print("リクエストエラーが発生しました。",e)
else:
    print("ウェブエージに正常にアクセスできました。")
finally:

    print("ウェブスクレイピング処理が完了しました。")
# Out:
# リクエストエラーが発生しました。 HTTPSConnectionPool(host='www.muashino-u.ac.jp', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x105a119a0>: Failed to resolve 'www.muashino-u.ac.jp' ([Errno 8] nodename nor servname provided, or not known)"))
# ウェブスクレイピング処理が完了しました。
